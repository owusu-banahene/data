# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import excel into pandas object roster
roster = pd.read_excel('roster.xlsx')

# %%
roster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   UPC                             213 non-null    object
#  1   Unit Name                       213 non-null    object
#  2   Position Title                  204 non-null    object
#  3   Soldier Name                    213 non-null    object
#  4   Rank                            213 non-null    object
#  5   Home Address                    213 non-null    object
#  6   Home City                       213 non-null    object
#  7   Home State                      213 non-null    object
#  8   Home ZIP Code                   213 non-null    object
#  9   Cell Phone Number (RLAS)        62 non-null     object
#  10  Home Phone Number (Raw) (RLAS)  193 non-null    object
#  11  Work Phone Number (RLAS)        36 non-null     object
# ...

# %%
roster.head()
# Out:
#      UPC           Unit Name        Position Title              Soldier Name  \
# 0  SBNAA  311 MC HSP (32 BD)   EMERGENCY PHYSICIAN       GEBHART MARK EDWARD
# 1  SBNAA  311 MC HSP (32 BD)  RADIOLOGY SPECIALIST  TRAYLOR MARQUISHA SYMONE
# 2  SBNAA  311 MC HSP (32 BD)   CRITICAL CARE NURSE      SUTTLES SCOTTIE LYNN
# 3  SBNAA  311 MC HSP (32 BD)  OPERATING ROOM NURSE    VONTRESS JENNIFER LYNN
# 4  SBNAA  311 MC HSP (32 BD)  BIOMEDICAL EQUIP SGT    EMERSON GAGE ROBERTSON
#
#   Rank                  Home Address     Home City Home State Home ZIP Code  \
# 0  LTC  10498 DAYTON CINCINNATI PIKE    MIAMISBURG         OH       45342.0
# 1  SPC        1305 FOUNTAIN LN APT J      COLUMBUS         OH       43213.0
# 2  MAJ          2426 FOREST HILLS RD  FOREST HILLS         KY       41527.0
# 3  1LT                 542 ALLARD PL  INDIANAPOLIS         IN       46202.0
# 4  SGT               711 W WENGER RD     ENGLEWOOD         OH       45322.0
#
# ...

# %%
roster['Home ZIP Code']= roster['Home ZIP Code'].astype(str)

# %%
roster[roster['Cell Phone Number (RLAS)'].notnull()].head()
# Out:
#       UPC           Unit Name        Position Title             Soldier Name  \
# 4   SBNAA  311 MC HSP (32 BD)  BIOMEDICAL EQUIP SGT   EMERSON GAGE ROBERTSON
# 5   SBNAA  311 MC HSP (32 BD)   CRITICAL CARE NURSE  BENZING OLIVIA NICHOLLE
# 9   SBNAA  311 MC HSP (32 BD)    CLINICAL NURSE ICW          WESTRICK TREY D
# 10  SBNAA  311 MC HSP (32 BD)     QM/CHEM EQUIP REP                 LI XIRUI
# 25  SBNAA  311 MC HSP (32 BD)       EMERGENCY NURSE  OSTERFELD SHANNON MARIE
#
#    Rank              Home Address      Home City Home State Home ZIP Code  \
# 4   SGT           711 W WENGER RD      ENGLEWOOD         OH       45322.0
# 5   CPT       7211 RIDGE CREEK RD     LOUISVILLE         KY       40291.0
# 9   1LT            5178 CITRUS DR       HILLIARD         OH       43026.0
# 10  SPC  411 WALNUT ST UNIT 15472  GREEN CV SPGS         FL       32043.0
# 25  MAJ             183 SHANDA DR         MONROE         OH       45050.0
#
# ...

# %%
#get top 5 sergeants

roster[(roster['Rank']=='SGT') & (roster['Cell Phone Number (RLAS)'].notnull())].head()
# Out:
#        UPC           Unit Name         Position Title            Soldier Name  \
# 4    SBNAA  311 MC HSP (32 BD)   BIOMEDICAL EQUIP SGT  EMERSON GAGE ROBERTSON
# 37   SBNAA  311 MC HSP (32 BD)   MEDICAL LAB SERGEANT      GRISSOM TIA NICOLE
# 45   SBNAA  311 MC HSP (32 BD)     EMERGENCY CARE SGT         ROACH MATTHEW W
# 97   SBNAA  311 MC HSP (32 BD)  RELIGIOUS AFFAIRS NCO    MAINS WENDELL LEE II
# 154  SBNAA  311 MC HSP (32 BD)     NUTRITION CARE NCO    REDWINE QUILLEAN ASA
#
#     Rank            Home Address     Home City Home State Home ZIP Code  \
# 4    SGT         711 W WENGER RD     ENGLEWOOD         OH       45322.0
# 37   SGT  8695 FESSLER BUXTON RD         PIQUA         OH       45356.0
# 45   SGT     175 TROTTERS CIRCLE      DELAWARE         US           nan
# 97   SGT  2457 STRAIGHT ST APT 3       BATAVIA         OH       45103.0
# 154  SGT      11301 CONGAREE WAY  INDIANAPOLIS         IN       46235.0
#
#     Cell Phone Number (RLAS) Home Phone Number (Raw) (RLAS)  \
# ...
